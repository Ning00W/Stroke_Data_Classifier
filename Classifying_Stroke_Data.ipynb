# %%
import json
import requests
from nltk.corpus import stopwords # stopword examples, 'its', 'on', 'the', etc <---- will be helpful later
# most pythonistas will rename pandas as pd, numpy as np, and datetime as dt for short (you don't have to)
import pandas as pd
import numpy as np
import datetime as dt

# %%
path = 'stroke_data.csv'
stroke = pd.read_csv(path, converters={'age': pd.eval})

# %%
stroke
# Out:
#        sex   age  hypertension  heart_disease  ever_married  work_type  \
# 0      1.0  63.0             0              1             1          4
# 1      1.0  42.0             0              1             1          4
# 2      0.0  61.0             0              0             1          4
# 3      1.0  41.0             1              0             1          3
# 4      1.0  85.0             0              0             1          4
# ...    ...   ...           ...            ...           ...        ...
# 40905  1.0  38.0             0              0             0          4
# 40906  0.0  53.0             0              0             1          4
# 40907  1.0  32.0             0              0             1          2
# 40908  1.0  42.0             0              0             1          3
# 40909  1.0  35.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                   1             228.69  36.6               1       1
# 1                   0             105.92  32.5               0       1
# 2                   1             171.23  34.4               1       1
# 3                   0             174.12  24.0               0       1
# 4                   1             186.21  29.0               1       1
# ...               ...                ...   ...             ...     ...
# 40905               1             120.94  29.7               1       0
# 40906               0              77.66  40.8               0       0
# 40907               0             231.95  33.2               0       0
# 40908               0             216.38  34.5               0       0
# 40909               0              95.01  28.0               0       0
#
# [40910 rows x 11 columns]

# %%
stroke.age
# Out:
# 0        63.0
# 1        42.0
# 2        61.0
# 3        41.0
# 4        85.0
#          ...
# 40905    38.0
# 40906    53.0
# 40907    32.0
# 40908    42.0
# 40909    35.0
# Name: age, Length: 40910, dtype: float64

# %%
stroke.smoking_status
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 40905    1
# 40906    0
# 40907    0
# 40908    0
# 40909    0
# Name: smoking_status, Length: 40910, dtype: int64

# %%
stroke.age.unique()
# Out:
# array([ 63.,  42.,  61.,  41.,  85.,  55.,  82.,  17.,  31.,  39.,  26.,
#         19.,  78.,  45.,  50.,  53.,  71.,  64.,  75.,  67.,  40.,  23.,
#         33.,  65.,  83.,  79.,  62.,  58.,  34.,  27.,  68.,  52.,  49.,
#         13.,  60.,  24.,  11.,  47.,  70.,  38.,  59.,  36.,  77.,  54.,
#         93.,  29.,  51.,  21.,  56.,  20.,  46.,  72.,  37.,  18.,  66.,
#         25.,  57.,  16.,  80.,  28.,  84.,  44.,  43.,  76.,  48.,   8.,
#         14.,  88.,  69.,  22.,  15.,  32.,  35.,  73.,  81.,  74.,  30.,
#         86.,  92.,   5.,  91.,   6.,  87.,   7.,   9.,  12.,  10.,  89.,
#         90.,   4.,   1.,   3.,  -2.,  -5.,  -4.,  -3.,  -1.,   2.,   0.,
#         -6.,  -9.,  95., 103.,  94.,  98.,  96., 102., 101.,  97.,  99.,
#        100.])

# %%
len(stroke.age.unique())
# Out:
# 111

# %%
1/111
# Out:
# 0.009009009009009009

# %%
stroke.avg_glucose_level
# Out:
# 0        228.69
# 1        105.92
# 2        171.23
# 3        174.12
# 4        186.21
#           ...
# 40905    120.94
# 40906     77.66
# 40907    231.95
# 40908    216.38
# 40909     95.01
# Name: avg_glucose_level, Length: 40910, dtype: float64

# %%
stroke.avg_glucose_level.unique()
# Out:
# array([228.69, 105.92, 171.23, ..., 125.2 ,  82.99, 166.29])

# %%
len(stroke.avg_glucose_level.unique())
# Out:
# 2903

# %%
1/2903
# Out:
# 0.0003444712366517396

# %%
def create_features(age, smoker, married):
    
    return{'smoker_status': smoker, 'age': age, 'ever_married': married}

# %%
features_and_labels = zip(stroke.age, stroke.smoking_status, stroke.stroke, stroke.ever_married)
features_and_labels

# %%
feature_sets = [ (create_features(age,smoker,married), stroke) for age, smoker,married, stroke in features_and_labels]
feature_sets
# Out:
# [({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 82.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 71.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 83.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 83.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 13.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 17.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 11.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 93.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 18.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 25.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 13.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 82.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 16.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 16.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 26.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 82.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 18.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 8.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 14.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 18.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 18.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 14.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 13.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 88.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 22.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 15.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 35.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 81.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 81.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 25.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 81.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 54.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 69.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 24.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 86.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 26.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 78.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 86.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 92.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 15.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 86.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 5.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 91.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 47.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 35.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 82.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 29.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 6.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 83.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 18.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 64.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 47.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 16.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 16.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 35.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 60.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 14.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 29.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 13.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 92.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 87.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 76.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 35.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 82.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 13.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 29.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 25.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 25.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 30.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 25.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 82.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 29.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 54.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 13.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 7.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 35.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 88.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 17.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 9.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 12.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 86.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 10.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 86.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 51.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 49.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 81.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 10.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 86.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 57.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 92.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 85.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 87.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 73.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 52.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 11.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 11.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 82.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 81.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 30.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 92.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 23.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 85.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 45.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 26.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 68.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 67.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 30.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 59.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 65.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 41.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 70.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 81.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 16.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 16.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 27.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 76.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 65.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 35.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 22.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 64.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 32.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 66.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 42.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 77.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 25.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 84.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 92.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 28.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 19.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 70.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 58.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 55.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 15.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 82.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 39.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 57.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 12.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 37.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 80.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 68.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 5.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 88.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 75.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 86.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 59.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 29.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 23.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 79.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 15.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 60.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 15.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 43.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 28.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 31.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 63.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 50.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 54.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 38.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 40.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 44.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 1, 'age': 48.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 56.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 71.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 51.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 61.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 56.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 24.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 78.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 62.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 27.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 53.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 86.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 36.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 34.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 14.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 69.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 45.0, 'ever_married': 1}, 0),
#  ({'smoker_status': 0, 'age': 87.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 74.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 33.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 72.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 20.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 47.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 21.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 62.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 35.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 0, 'age': 46.0, 'ever_married': 1}, 1),
#  ({'smoker_status': 1, 'age': 39.0, 'ever_married': 1}, 1),
#  ...]

# %%
import math
import nltk

print(len(feature_sets))
split_num = math.floor(len(feature_sets)*.8)
print(split_num)

import random
random.shuffle(feature_sets)
# Out:
# 40910
# 32728

# %%
training_set = feature_sets[:split_num]
testing_set = feature_sets[split_num:]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
print(nltk.classify.accuracy(classifier, testing_set))
# Out:
# 0.7894801253181907

# %%
len(feature_sets)
# Out:
# 40910

# %%
68* .8
# Out:
# 54.400000000000006

# %%
training_set = feature_sets[:54]
testing_set = feature_sets[54:]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.classify(create_features(63,1,1))
# Out:
# 1

# %%
print(nltk.classify.accuracy(classifier, testing_set))
# Out:
# 0.7894801253181907
